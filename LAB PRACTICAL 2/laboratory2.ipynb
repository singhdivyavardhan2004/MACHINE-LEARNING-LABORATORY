# %%
import pandas as pd

data = pd.read_csv("enjoy_sport_dataset.csv")
data
# Out:
#      sky air_temp humidity    wind water forecast enjoy_spot
# 0  sunny     warm   normal  strong  warm     same        yes
# 1  sunny     warm     high  strong  warm     same        yes
# 2  rainy     cold     high  strong  warm   change         no
# 3  sunny     warm     high  strong  cool   change        yes

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

print("Features:\n", X)
print("\nTarget:\n", y)
# Out:
# Features:
#  [['sunny' 'warm' 'normal' 'strong' 'warm' 'same']
#  ['sunny' 'warm' 'high' 'strong' 'warm' 'same']
#  ['rainy' 'cold' 'high' 'strong' 'warm' 'change']
#  ['sunny' 'warm' 'high' 'strong' 'cool' 'change']]
#
# Target:
#  ['yes' 'yes' 'no' 'yes']

# %%
import numpy as np

X = np.array([
    ["sunny","warm","normal","strong","warm","same"],
    ["sunny","warm","high","strong","warm","same"],
    ["rainy","cold","high","strong","warm","change"],
    ["sunny","warm","high","strong","cool","change"]
])

y = np.array(["yes","yes","no","yes"])

# %%
for i in range(len(y)):
    if y[i] == "yes":
        S = X[i].copy()
        break

print("Initial Specific Boundary S:", S)
# Out:
# Initial Specific Boundary S: ['sunny' 'warm' 'normal' 'strong' 'warm' 'same']

# %%
for i in range(len(y)):
    print("\nExample", i+1, ":", X[i], "→", y[i])

    if y[i] == "yes":
        for j in range(n):
            if S[j] != X[i][j]:
                S[j] = "?"

        G = [g for g in G if all(g[j] == "?" or g[j] == S[j] for j in range(n))]

        print("Updated S:", S)
        print("Updated G:", G)

    else:
        new_G = []

        for g in G:

            if all(g[j] == "?" or g[j] == X[i][j] for j in range(n)):

                for j in range(n):

                    if S[j] != "?" and S[j] != X[i][j]:
                        new_h = g.copy()
                        new_h[j] = S[j]
                        new_G.append(new_h)
            else:
                new_G.append(g)

        G = new_G
        print("Negative example → G specialized")
        print("S remains:", S)
        print("Updated G:", G)
# Out:
# Example 1 : ['sunny' 'warm' 'normal' 'strong' 'warm' 'same'] → yes
# Updated S: ['sunny' 'warm' 'normal' 'strong' 'warm' 'same']
# Updated G: [['?', '?', '?', '?', '?', '?']]
#
# Example 2 : ['sunny' 'warm' 'high' 'strong' 'warm' 'same'] → yes
# Updated S: ['sunny' 'warm' '?' 'strong' 'warm' 'same']
# Updated G: [['?', '?', '?', '?', '?', '?']]
#
# Example 3 : ['rainy' 'cold' 'high' 'strong' 'warm' 'change'] → no
# Negative example → G specialized
# S remains: ['sunny' 'warm' '?' 'strong' 'warm' 'same']
# Updated G: [[np.str_('sunny'), '?', '?', '?', '?', '?'], ['?', np.str_('warm'), '?', '?', '?', '?'], ['?', '?', '?', '?', '?', np.str_('same')]]
#
# Example 4 : ['sunny' 'warm' 'high' 'strong' 'cool' 'change'] → yes
# Updated S: ['sunny' 'warm' '?' 'strong' '?' '?']
# Updated G: [[np.str_('sunny'), '?', '?', '?', '?', '?'], ['?', np.str_('warm'), '?', '?', '?', '?']]

# %%
print("\nFinal Specific Hypothesis S:", S)
print("Final General Hypotheses G:", G)
# Out:
# Final Specific Hypothesis S: ['sunny' 'warm' '?' 'strong' '?' '?']
# Final General Hypotheses G: [[np.str_('sunny'), '?', '?', '?', '?', '?'], ['?', np.str_('warm'), '?', '?', '?', '?']]
